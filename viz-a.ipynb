# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
cars = pd.read_csv('USA_cars_datasets.csv')

# %% [markdown]
# ## US Car Auctions Dataset Head Sample

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %% [markdown]
# ## US Car Auctions Dataset Description

# %%
cars.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
# ...

# %% [markdown]
# ## US Car Auctions Dataset Info

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   float64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 253.9+ KB

# %% [markdown]
# ## US Car Auctions Dataset Visualization

# %%
excluded_brands = ['heartland', 'peterbilt', 'harley-davidson']
filtered_data = cars[~cars['brand'].isin(excluded_brands)]
filtered_data = round(filtered_data.groupby('brand')['mileage'].mean().sort_values(ascending=False))

average_mileage_brand_data = pd.DataFrame(filtered_data)

average_mileage_brand_data.reset_index(inplace=True)
average_mileage_brand_data = average_mileage_brand_data.rename(columns = {'index':'rank'})

average_mileage_brand_data
# Out:
#             brand   mileage
# 0          toyota  274117.0
# 1           acura  120380.0
# 2            audi  118091.0
# 3           honda   91599.0
# 4           mazda   82647.0
# 5        chrysler   73004.0
# 6       chevrolet   65124.0
# 7             gmc   58549.0
# 8         hyundai   56684.0
# 9             kia   56609.0
# 10  mercedes-benz   54597.0
# 11        lincoln   52123.0
# 12           ford   52084.0
# 13            bmw   47846.0
# 14          dodge   44185.0
# 15         nissan   42426.0
# 16       cadillac   40196.0
# 17           jeep   38723.0
# 18          buick   37927.0
# 19       maserati   37021.0
# 20            ram   30421.0
# 21           land   26614.0
# 22       infiniti   25023.0
# 23          lexus   22391.0
# 24         jaguar   20849.0

# %%
X = average_mileage_brand_data['brand'].values
y = average_mileage_brand_data['mileage'].values

# %%
plt.bar(X, y, color='red')
plt.xlabel('Brand')
plt.ylabel('Average Mileage')
plt.title('Average Mileage of Used Cars at Auction By Brand')
# plt.figure(figsize=(40, 40))

# plt.subplots(figsize=(5,5))

# f = plt.figure() 
# f.set_figwidth(20) 
# f.set_figheight(16) 

plt.show()

# %%
x = sns.barplot(x='brand', y='mileage', data=average_mileage_brand_data)
x.set_xticklabels(labels=average_mileage_brand_data['brand'], rotation=90)
print()

# %% [markdown]
# ## Conclusions
# 1. Toyota is by far the most successful brand in terms of average driven miles for vehicles still in use.
# 2. Toyota vehicles retain value very well, given that they still go up for auction with nearly 300000 miles driven.
# 3. There is no clear relationship between brand premium and vehicle retention. Mass-market and luxury brands are both fairly evenly distributed across the spectrum of average miles driven before being put up for auction.
